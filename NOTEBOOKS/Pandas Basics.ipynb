# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline

# %%
s = pd.Series([2, 4, 6, 8, 10, 12], index='alpha beta gamma delta epsilon eta'.split())
s
# Out:
# alpha       2
# beta        4
# gamma       6
# delta       8
# epsilon    10
# eta        12
# dtype: int64

# %%
s['alpha']
# Out:
# 2

# %%
s.gamma
# Out:
# 6

# %%
values = pd.Series([10, 20, 30, 40, 50])
values
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
df = pd.read_csv('../DATA/parasite_data.csv')
df.head()
# Out:
#   Virulence  Replicate  ShannonDiversity
# 0       0.5          1          0.059262
# 1       0.5          2          1.093600
# 2       0.5          3          1.139390
# 3       0.5          4          0.547651
# 4       0.5          5          0.065928

# %%
data = df[(df['Virulence'] == "0.5") & (df['ShannonDiversity'] > 1.5)]
data.plot('Replicate', 'ShannonDiversity')
# Out:
# <AxesSubplot:xlabel='Replicate'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Virulence         350 non-null    object
#  1   Replicate         350 non-null    int64
#  2   ShannonDiversity  350 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 8.3+ KB

# %%
df.describe()
# Out:
#         Replicate  ShannonDiversity
# count  350.000000        350.000000
# mean    25.500000          0.836447
# std     14.451529          0.773476
# min      1.000000          0.000000
# 25%     13.000000          0.000000
# 50%     25.500000          0.845693
# 75%     38.000000          1.533692
# max     50.000000          2.900810

# %%
values = [
    [100, 110, 120, 130, 140], 
          [200, 210, 220, 230, 240], 
          [300, 310, 320, 330, 340], 
          [400, 410, 420, 430, 440], 
          [500, 510, 520, 530, 540], 
          [600, 610, 620, 630, 640],
]

columns = 'alpha beta gamma delta epsilon'.split()
rows = 'a b c d e f'.split()
df = pd.DataFrame(values,index=rows, columns=columns)
df
# Out:
#    alpha  beta  gamma  delta  epsilon
# a    100   110    120    130      140
# b    200   210    220    230      240
# c    300   310    320    330      340
# d    400   410    420    430      440
# e    500   510    520    530      540
# f    600   610    620    630      640

# %%
df['beta']
# Out:
# a    110
# b    210
# c    310
# d    410
# e    510
# f    610
# Name: beta, dtype: int64

# %%
df[['gamma', 'delta']]
# Out:
#    gamma  delta
# a    120    130
# b    220    230
# c    320    330
# d    420    430
# e    520    530
# f    620    630

# %%
df['a':'b']
# Out:
#    alpha  beta  gamma  delta  epsilon
# a    100   110    120    130      140
# b    200   210    220    230      240

# %%
df['a':'a']
# Out:
#    alpha  beta  gamma  delta  epsilon
# a    100   110    120    130      140

# %%
#df.loc[ROW, COL]
df.loc[['a', 'b']]
# Out:
#    alpha  beta  gamma  delta  epsilon
# a    100   110    120    130      140
# b    200   210    220    230      240

# %%
df.loc[['a','b'], 'delta']
# Out:
# a    130
# b    230
# Name: delta, dtype: int64

# %%
df.loc[['a','b'], ['delta', 'gamma']]
# Out:
#    delta  gamma
# a    130    120
# b    230    220

# %%
df.loc['a', 'gamma']
# Out:
# 120

# %%
df.at['a', 'gamma']
# Out:
# 120

# %%
df
# Out:
#    alpha  beta  gamma  delta  epsilon
# a    100   110    120    130      140
# b    200   210    220    230      240
# c    300   310    320    330      340
# d    400   410    420    430      440
# e    500   510    520    530      540
# f    600   610    620    630      640

# %%
df['alpha'] * 2
# Out:
# a     200
# b     400
# c     600
# d     800
# e    1000
# f    1200
# Name: alpha, dtype: int64

# %%
df * 2
# Out:
#    alpha  beta  gamma  delta  epsilon
# a    200   220   2160    260      280
# b    400   420   3960    460      480
# c    600   620   5760    660      680
# d    800   820   7560    860      880
# e   1000  1020   9360   1060     1080
# f   1200  1220  11160   1260     1280

# %%
df['gamma'] *= 3
df
# Out:
#    alpha  beta  gamma  delta  epsilon
# a    100   110   9720    130      140
# b    200   210  17820    230      240
# c    300   310  25920    330      340
# d    400   410  34020    430      440
# e    500   510  42120    530      540
# f    600   610  50220    630      640

# %%
pres = pd.read_csv('../DATA/presidents.csv', names='term fname lname bplace bstate party'.split(), index_col=0)
pres
# Out:
#                          fname       lname                      bplace  \
# term
# 1                       George  Washington         Westmoreland County
# 2                         John       Adams          Braintree, Norfolk
# 3                       Thomas   Jefferson           Albermarle County
# 4                        James     Madison                 Port Conway
# 5                        James      Monroe         Westmoreland County
# 6                  John Quincy       Adams          Braintree, Norfolk
# 7                       Andrew     Jackson                      Waxhaw
# 8                       Martin   Van Buren                  Kinderhook
# 9                William Henry    Harrison                    Berkeley
# 10                        John       Tyler         Charles City County
# 11                  James Knox        Polk          Mecklenburg County
# 12                     Zachary      Taylor               Orange County
# ...

# %%
party_counts = pres['party'].value_counts()
party_counts
# Out:
# Republican                 20
# Democratic                 16
# Democratic - Republican     4
# Whig                        4
# no party                    1
# Federalist                  1
# Name: party, dtype: int64

# %%
party_counts.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#    alpha  beta  gamma  delta  epsilon
# a    100   110   9720    130      140
# b    200   210  17820    230      240
# c    300   310  25920    330      340
# d    400   410  34020    430      440
# e    500   510  42120    530      540
# f    600   610  50220    630      640

# %%
df['eta'] = df['alpha'] + df['beta']
df
# Out:
#    alpha  beta  gamma  delta  epsilon   eta
# a    100   110   9720    130      140   210
# b    200   210  17820    230      240   410
# c    300   310  25920    330      340   610
# d    400   410  34020    430      440   810
# e    500   510  42120    530      540  1010
# f    600   610  50220    630      640  1210

# %%
df2 = df.drop('delta', axis=1)
df2
# Out:
#    alpha  beta  gamma  epsilon   eta
# a    100   110   9720      140   210
# b    200   210  17820      240   410
# c    300   310  25920      340   610
# d    400   410  34020      440   810
# e    500   510  42120      540  1010
# f    600   610  50220      640  1210

# %%
df.drop('delta', axis=1, inplace=True)
df
# Out:
#    alpha  beta  gamma  epsilon   eta
# a    100   110   9720      140   210
# b    200   210  17820      240   410
# c    300   310  25920      340   610
# d    400   410  34020      440   810
# e    500   510  42120      540  1010
# f    600   610  50220      640  1210

# %%
df.columns
# Out:
# Index(['alpha', 'beta', 'gamma', 'epsilon', 'eta'], dtype='object')

# %%
df.columns = ['a', 'b', 'c', 'd', 'e']
df
# Out:
#      a    b      c    d     e
# a  100  110   9720  140   210
# b  200  210  17820  240   410
# c  300  310  25920  340   610
# d  400  410  34020  440   810
# e  500  510  42120  540  1010
# f  600  610  50220  640  1210

# %%
df.values
# Out:
# array([[  100,   110,  9720,   140,   210],
#        [  200,   210, 17820,   240,   410],
#        [  300,   310, 25920,   340,   610],
#        [  400,   410, 34020,   440,   810],
#        [  500,   510, 42120,   540,  1010],
#        [  600,   610, 50220,   640,  1210]], dtype=int64)

# %%
df
# Out:
#      a    b      c    d     e
# a  100  110   9720  140   210
# b  200  210  17820  240   410
# c  300  310  25920  340   610
# d  400  410  34020  440   810
# e  500  510  42120  540  1010
# f  600  610  50220  640  1210

# %%
df['c'].median()
# Out:
# 29970.0

# %%
df['c'].mean()
# Out:
# 29970.0

# %%
df['c'].std()
# Out:
# 15153.712416434462
